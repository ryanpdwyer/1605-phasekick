# %% [markdown]
# Separate the AC and DC components of the tr-EFM signal. This is a good initial guess.

# %%
# %matplotlib inline
from __future__ import division, print_function
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import h5py
# import sklearn
from scipy import linalg, signal, optimize
import lockin
import pandas as pd
import phasekick2 as pk2
import phasekick as pk
import tqdm
import munch
import sigutils

def normalize(x, norm=1):
    return x / np.sum(x**norm)**(1.0/norm)

def gr2t(gr):
    half_periods = gr["half periods [s]"][:]
    N2even = gr.attrs['Calc BNC565 CantClk.N2 (even)']
    t1 = gr.attrs['Abrupt BNC565 CantClk.t1 [s]']
    t2 = np.sum(gr["half periods [s]"][:N2even+1])
    tp = np.sum(gr["half periods [s]"][N2even+1:])
    t0 = -t1 - gr["half periods [s]"][0]
    dt = gr['dt [s]'].value
    x = gr['cantilever-nm'][:]
    return np.arange(x.size)*dt + t0

def signal_average_gr(gr, ti, tf):
    b = munch.Munch()
    xs = []
    ts = []
    for ds in tqdm.tqdm(gr.values()):
        t = gr2t(ds)
        m = (t > ti) & (t < tf)
        ts.append(t[m])
        x = ds['cantilever-nm'][:]
        xs.append(x[m])

    ts = np.array(ts)
    b.t = np.mean(ts, axis=0)
    x_array = np.array(xs)
    b.x = np.mean(x_array, axis=0)
    b.t_array = ts
    b.x_array = x_array
    return b

# %%
# fh = h5py.File("../../data/tr-efm/151217-234238-20sun-df-384.h5", "r")

# %%
fh2 = h5py.File("../../data/tr-efm/151218-003450-100sun-784.h5", "r")

# %%
# fh3 = h5py.File("../../data/tr-efm/151217-211131-1sun-df.h5", "r")

# %%
params =   {'fp': 4000,
             'fc': 15000,
             't_phase': -0.052,
             'ti': -54e-3,
             'tf': 6e-3,
             'Ndec': 15}

# %%
df = pd.read_table('taps.txt', header=None)

# %%
taps = normalize(df[0].values)

# %%
# Out:
# 1.0000000000000002

# %%
b = signal_average_gr(fh2['data'], -4.5e-3, 10e-3)
# Out:
# 100%|██████████| 784/784 [00:06<00:00, 128.79it/s]

# %%
for i in xrange(4):
    t= b.t_array[i, :]*1e6
    m = pk.masklh(t, -20, 20)
    plt.plot(t[m], b.x_array[i, :][m])

# %%
fir = signal.parzen(200)
fir = fir/np.sum(fir)

# %%
plt.plot(fir)

# %%
sum(fh2['data/0000/half periods [s]'][:-1])
# Out:
# 0.050126449999999892

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-da02ce9c27dd> in <module>()
# ----> 1 li.t1
#
# AttributeError: 'LockIn' object has no attribute 't1'

# %%
li = lockin.LockIn(b.t, b.x, 1e6)
li.run(fir=fir)
li.phase(tf=-0.001)

# %%
li4 = lockin.LockIn(b.t, b.x, 1e6)
li4.lock2(fp=2e3, fc=8e3)
li4.phase(tf=-0.001)
# Out:
# Response:
# f   mag       dB
#     0.000 1.000    0.000
#  1000.000 0.983   -0.151
#  2000.000 0.927   -0.657
#  8000.000 0.095  -20.459
# 16000.000 0.000 -101.856
# 30930.247 0.000 -133.788
# 61860.495 0.000 -153.254
# 500000.000 0.000 -340.558

# %%
li4.

# %%
fir_notch = normalize(signal.parzen(128))

# %%
li2 = lockin.LockIn(b.t, b.x, 1e6)
li2.run(fir=fir_notch)
li2.phase(tf=-0.001)

# %%
li3 = lockin.LockIn(b.t, b.x, 1e6)
li3.run(fir=taps)
li3.phase(tf=-0.001)

# %%
plt.plot(li('t')*1e3 + li.fir.size/2 * 1e-3, li('df'))
plt.plot(li2('t')*1e3 + li2.fir.size/2 * 1e-3, li2('df'))
plt.plot(li3('t')*1e3 + li3.fir.size/2 * 1e-3, li3('df'))
plt.plot(li4('t')*1e3 + li4.fir.size/2 * 1e-3, li4('df'))
plt.xlim(-0.1, 0.5)
plt.ylim(-150, 10)
# Out:
# (-150, 10)

# %%
fir_online = np.array([
        
    ])

# %%
# Out:
# 1.0291063819430171

# %%
sigutils.bode_zz([(fir_notch,), (li.fir,), (taps,)], fs=1e6, xlog=True, xlim=(1e2, 7e4))
# Out:
# (<matplotlib.figure.Figure at 0x124bc6f90>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x12067b8d0>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x12608cf90>))

# %%
plt.plot(li('t')*1e3 + li.fir.size/2 * 1e-3, li('A'))
plt.plot(li2('t')*1e3 + li2.fir.size/2 * 1e-3, li2('A'))
plt.plot(li3('t')*1e3 + li3.fir.size/2 * 1e-3, li3('A'))
plt.xlim(-0.1, 0.5)
# Out:
# (-0.1, 0.5)

# %%
fir_g = normalize(signal.gaussian(2056*2+1, std=512)[2056:])
plt.plot(fir_g)

# %%
fir = signal.parzen(200)

sigutils.bode_zz([(normalize(signal.parzen(200)),),
                 (normalize(signal.parzen(128)),),
                 (fir_g,)],  fs=1e6, xlim=(50000, 75000))

# %%
sigutils.bode_z(fir_g,  fs=1e6, xlog=True)
# Out:
# (<matplotlib.figure.Figure at 0x120bdb910>,
#  (<matplotlib.axes._subplots.AxesSubplot at 0x121623a50>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x1217748d0>))

# %%
m = pk.masklh(trefm.t50, -0.052, -0.048)
plt.plot(trefm.t50[m], trefm.df50[m])

# %%
fir = lockin.lock2(66000, params['fp'], params['fc'], fs=1e6)
# Out:
# Response:
# f   mag       dB
#     0.000 1.000    0.000
#  2000.000 0.982   -0.161
#  4000.000 0.921   -0.715
# 15000.000 0.098  -20.164
# 30000.000 0.000 -101.125
# 33000.000 0.000 -110.366
# 66000.000 0.000 -141.187
# 500000.000 0.000 -196.320

# %%
fir
# Out:
# array([ -5.17360354e-22,   2.49403503e-09,   1.25508768e-08,
#          3.41784530e-08,   7.14831704e-08,   1.28536678e-07,
#          2.09226463e-07,   3.17090181e-07,   4.55133755e-07,
#          6.25633537e-07,   8.29923033e-07,   1.06816501e-06,
#          1.33911009e-06,   1.63984340e-06,   1.96552111e-06,
#          2.30909925e-06,   2.66105765e-06,   3.00912225e-06,
#          3.33798975e-06,   3.62905874e-06,   3.86017244e-06,
#          4.00537833e-06,   4.03471048e-06,   3.91400124e-06,
#          3.60472878e-06,   3.06390792e-06,   2.24403151e-06,
#          1.09307028e-06,  -4.45461114e-07,  -2.43236398e-06,
#         -4.93253354e-06,  -8.01464746e-06,  -1.17507577e-05,
#         -1.62157789e-05,  -2.14868673e-05,  -2.76426851e-05,
#         -3.47625453e-05,  -4.29254345e-05,  -5.22089112e-05,
#         -6.26878796e-05,  -7.44332394e-05,  -8.75104141e-05,
#         -1.01977763e-04,  -1.17884884e-04,  -1.35270810e-04,
#         -1.54162121e-04,  -1.74570970e-04,  -1.96493048e-04,
#         -2.19905503e-04,  -2.44764821e-04,  -2.71004710e-04,
#         -2.98533988e-04,  -3.27234511e-04,  -3.56959170e-04,
#         -3.87529969e-04,  -4.18736227e-04,  -4.50332924e-04,
#         -4.82039228e-04,  -5.13537220e-04,  -5.44470863e-04,
#         -5.74445229e-04,  -6.03026021e-04,  -6.29739416e-04,
#         -6.54072251e-04,  -6.75472575e-04,  -6.93350598e-04,
#         -7.07080040e-04,  -7.15999906e-04,  -7.19416695e-04,
#         -7.16607053e-04,  -7.06820869e-04,  -6.89284817e-04,
#         -6.63206346e-04,  -6.27778086e-04,  -5.82182686e-04,
#         -5.25598037e-04,  -4.57202870e-04,  -3.76182698e-04,
#         -2.81736064e-04,  -1.73081051e-04,  -4.94620294e-05,
#          8.98434347e-05,   2.45517537e-04,   4.18195128e-04,
#          6.08456599e-04,   8.16820817e-04,   1.04373818e-03,
#          1.28958384e-03,   1.55465120e-03,   1.83914571e-03,
#          2.14317903e-03,   2.46676365e-03,   2.80980804e-03,
#          3.17211236e-03,   3.55336475e-03,   3.95313838e-03,
#          4.37088918e-03,   4.80595436e-03,   5.25755177e-03,
#          5.72478007e-03,   6.20661978e-03,   6.70193526e-03,
#          7.20947756e-03,   7.72788821e-03,   8.25570384e-03,
#          8.79136181e-03,   9.33320660e-03,   9.87949711e-03,
#          1.04284147e-02,   1.09780722e-02,   1.15265230e-02,
#          1.20717719e-02,   1.26117852e-02,   1.31445026e-02,
#          1.36678483e-02,   1.41797435e-02,   1.46781182e-02,
#          1.51609243e-02,   1.56261474e-02,   1.60718197e-02,
#          1.64960321e-02,   1.68969465e-02,   1.72728075e-02,
#          1.76219534e-02,   1.79428277e-02,   1.82339886e-02,
#          1.84941192e-02,   1.87220356e-02,   1.89166952e-02,
#          1.90772036e-02,   1.92028208e-02,   1.92929657e-02,
#          1.93472205e-02,   1.93653335e-02,   1.93472205e-02,
#          1.92929657e-02,   1.92028208e-02,   1.90772036e-02,
#          1.89166952e-02,   1.87220356e-02,   1.84941192e-02,
#          1.82339886e-02,   1.79428277e-02,   1.76219534e-02,
#          1.72728075e-02,   1.68969465e-02,   1.64960321e-02,
#          1.60718197e-02,   1.56261474e-02,   1.51609243e-02,
#          1.46781182e-02,   1.41797435e-02,   1.36678483e-02,
#          1.31445026e-02,   1.26117852e-02,   1.20717719e-02,
#          1.15265230e-02,   1.09780722e-02,   1.04284147e-02,
#          9.87949711e-03,   9.33320660e-03,   8.79136181e-03,
#          8.25570384e-03,   7.72788821e-03,   7.20947756e-03,
#          6.70193526e-03,   6.20661978e-03,   5.72478007e-03,
#          5.25755177e-03,   4.80595436e-03,   4.37088918e-03,
#          3.95313838e-03,   3.55336475e-03,   3.17211236e-03,
#          2.80980804e-03,   2.46676365e-03,   2.14317903e-03,
#          1.83914571e-03,   1.55465120e-03,   1.28958384e-03,
#          1.04373818e-03,   8.16820817e-04,   6.08456599e-04,
#          4.18195128e-04,   2.45517537e-04,   8.98434347e-05,
#         -4.94620294e-05,  -1.73081051e-04,  -2.81736064e-04,
#         -3.76182698e-04,  -4.57202870e-04,  -5.25598037e-04,
#         -5.82182686e-04,  -6.27778086e-04,  -6.63206346e-04,
#         -6.89284817e-04,  -7.06820869e-04,  -7.16607053e-04,
#         -7.19416695e-04,  -7.15999906e-04,  -7.07080040e-04,
#         -6.93350598e-04,  -6.75472575e-04,  -6.54072251e-04,
#         -6.29739416e-04,  -6.03026021e-04,  -5.74445229e-04,
#         -5.44470863e-04,  -5.13537220e-04,  -4.82039228e-04,
#         -4.50332924e-04,  -4.18736227e-04,  -3.87529969e-04,
#         -3.56959170e-04,  -3.27234511e-04,  -2.98533988e-04,
#         -2.71004710e-04,  -2.44764821e-04,  -2.19905503e-04,
#         -1.96493048e-04,  -1.74570970e-04,  -1.54162121e-04,
#         -1.35270810e-04,  -1.17884884e-04,  -1.01977763e-04,
#         -8.75104141e-05,  -7.44332394e-05,  -6.26878796e-05,
#         -5.22089112e-05,  -4.29254345e-05,  -3.47625453e-05,
#         -2.76426851e-05,  -2.14868673e-05,  -1.62157789e-05,
#         -1.17507577e-05,  -8.01464746e-06,  -4.93253354e-06,
#         -2.43236398e-06,  -4.45461114e-07,   1.09307028e-06,
#          2.24403151e-06,   3.06390792e-06,   3.60472878e-06,
#          3.91400124e-06,   4.03471048e-06,   4.00537833e-06,
#          3.86017244e-06,   3.62905874e-06,   3.33798975e-06,
#          3.00912225e-06,   2.66105765e-06,   2.30909925e-06,
#          1.96552111e-06,   1.63984340e-06,   1.33911009e-06,
#          1.06816501e-06,   8.29923033e-07,   6.25633537e-07,
#          4.55133755e-07,   3.17090181e-07,   2.09226463e-07,
#          1.28536678e-07,   7.14831704e-08,   3.41784530e-08,
#          1.25508768e-08,   2.49403503e-09,  -5.17360354e-22])

# %%
lis = []
for ds in fh['data'].values():
    li = pk.gr2lock(ds, fp=params['fp'], fc=params['fc'])
    li.phase(tf=params['tf'])
    lis.append(li)

# %%
xDCs2 = []
t2 = []
for ds in tqdm.tqdm(fh2['data'].values()):
    t = pk.gr2t(ds)
    m = (t > params['ti']) & (t < params['tf'])
    t2.append(t[m])
    x = ds['cantilever-nm'][:]
    xDC = signal.fftconvolve(x, fir, mode='same')
    xDCs2.append(xDC[m])

t2 = np.array(t2)
t2 = np.mean(t2, axis=0)
xDCs2 = np.array(xDCs2)
xDC2 = np.mean(xDCs2, axis=0)

# %%
xDCs3 = []
t3 = []
for ds in tqdm.tqdm(fh3['data'].values()):
    t = pk.gr2t(ds)
    m = (t > params['ti']) & (t < 54e-3)
    t3.append(t[m])
    x = ds['cantilever-nm'][:]
    xDC = signal.fftconvolve(x, fir, mode='same')
    xDCs3.append(xDC[m])

t3 = np.array(t3)
t3 = np.mean(t3, axis=0)
xDCs3 = np.array(xDCs3)
xDC3 = np.mean(xDCs3, axis=0)

# %%
xs = []
xDCs = []
ts = []
zs = []
f0s = []

for li in tqdm.tqdm(lis):
    m = (li.t > params['ti']) & (li.t < params['tf'])
    xDC = signal.fftconvolve(li.x, li.fir, mode='same')
#     li.absolute_phase(m)
    xs.append(li.x[m])
    xDCs.append(xDC[m])
    ts.append(li.t[m])
    zs.append(li.z[m])
    f0s.append(li.f0corr)

xs = np.array(xs)
ts = np.array(ts)
zs = np.array(zs)
f0s = np.array(f0s)

# %%
xDCs = np.array(xDCs)

# %%
tm = np.mean(ts, axis=0)
xDCm = np.mean(xDCs, axis=0)

# %%
plt.plot(tm*1e3, xDCm)
plt.plot(t2*1e3, xDC2)
plt.plot(t3*1e3, xDC3)
plt.axhline(y=-0.04, color='0.5', zorder=0)
plt.xlim(-0.2, 1.6)
plt.ylim(-0.1, 1.2)
plt.xlabel("Time $t$ [ms]")
plt.ylabel("DC displacement $x$ [nm]")

# %%
with h5py.File("DC-data.h5", "w") as fh:
    gr = fh.create_group('20')
    gr['t'] = tm*1e3
    gr['x'] = xDCm

# %%
from sklearn import linear_model

# %%
omp = linear_model.OrthogonalMatchingPursuit(n_nonzero_coefs=5, )

# %%
# ?omp.

# %%
fig, axes = plt.subplots(ncols=3)
lims = [
    # tuple is tmin, tmax, t0
    (-50.3e-3, -49.5e-3, -50e-3),
    (-0.5e-3, 2.2e-3, 0),
    (2.8e-3, 4.5e-3, 3e-3)
]
guesses = [
    np.array([-0.05, 1.33, 1/(2*np.pi), -50.1]),
    np.array([-0.04, 0.3, 2/(2*np.pi), 0.12]),
    np.array([0, -1.75, 1/(2*np.pi), 3])
]
datas = []
fits = []
for (tmin, tmax, t0guess), p0 in zip(lims, guesses):
    mplot = (tm > tmin) & (tm < tmax)
    t = tm[mplot]*1e3
    x = xDCm[mplot]
    print(t.size)
    print(x.size)
    datas.append((t, x))
    func = lambda t, x0, dx, tau, t0: np.where(t < t0, x0, x0 + dx*np.exp(-(t-t0)/tau))
    popt, pcov = optimize.curve_fit(func,
                      t, x, p0=p0)
    fits.append((popt, pcov, func(t, *popt), func))
    
    
    
for ax, (t, x), fit, guess in zip(axes, datas, fits, guesses):
    
    ax.plot(t, x)
    ax.plot(t, fit[3](t, *guess))
#     ax.plot(t, fit[2])
    
fig.tight_layout()
# Out:
# 800
# 800
# 2700
# 2700
# 1700
# 1700

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x19cfde410>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a4a797d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x18eebc6d0>], dtype=object)

# %%
for t, x, z, li, xDC in [(ts[i], xs[i], zs[i], lis[i], xDCs[i]) for i in xrange(0, len(xDCs), 100)]:
#     line, = plt.plot(t, z.real)
    plt.plot(t, xDC)
    plt.xlim(-0.051, -0.047)
    plt.ylim(-0.5, 1.5)
#     plt.plot(t, x_filt)
#     plt.xlim(-10e-3, -9.96e-3)
    
#     plt.plot(t, abs(z), color=line.get_color(), linewidth=2)
#     plt.plot(t, z.imag, color=line.get_color(), linestyle='--')

# %%
for t, x, z, li, xDC in [(ts[i], xs[i], zs[i], lis[i], xDCs[i]) for i in xrange(0, len(xDCs), 100)]:
#     line, = plt.plot(t, z.real)
    plt.plot(t, xDC)
    plt.xlim(-2e-3, 5e-3)
    plt.ylim(-2, 0.5)

# %%
plt.plot(t, z * np.exp(2*np.pi*))

# %%
for li in lis:
    li.absolute_phase()

# %%
for t, x, z in [(ts[i], xs[i], zs[i]) for i in xrange(0, len(ts), 100)]:
    line, = plt.plot(t, abs(z))
    plt.plot(t, z.imag, color=line.get_color(), linestyle='--')

# %%
for t, x, z in [(ts[i], xs[i], zs[i]) for i in xrange(0, len(ts), 100)]:
    line, = plt.plot(t, x)

# %%
plt.semilogy(1-np.cumsum(d**2) / sum(d**2))
